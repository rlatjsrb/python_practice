# %%
import requests
import lxml.html

# %%
def main():
    # 여러 페이지에서 크롤링을 위해 Session 사용
    session = requests.Session()  
    # scrape_list_page() 함수를 호출해서 제너레이터를 추출
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    for url in urls:
        response = session.get(url)    # Session을 사용해 상세 페이지를 추출
        ebook = scrape_detail_page(response)    # 상세 페이지에서 상세 정보를 추출
        print(ebook)    # 상세 정보 출력

# %%
def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        yield url

# %%
def scrape_detail_page(response):
    """
    상세 페이지의 Response에서 책 정보를 dict로 추출
    """
    root = lxml.html.fromstring(response.content)
    ebook = {
        'url': response.url,
        'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
        'price': root.cssselect('.pbr strong')[0].text_content(),
        'content': [p.text_content()\
            for p in root.cssselect('#tabs_3 .hanbit_edit_view p')]
    }
    return ebook

# %%
if __name__ == '__main__':
    main()
# Out:
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7623190015', 'title': '최신 관리회계', 'price': '28,000', 'content': ['', '\r\n\t\t\t\t1부 관리회계시스템\r\n', '1장 관리회계', '1절 관리회계의 개념', '2절 경영과 관리회계', '3절 회계정보시스템', '2장 관리회계시스템(MAS)', '1절 관리회계와 의사결정', '2절 관리회계시스템의 특성', '3절 관리회계시스템의 활용', '3장 원가관리', '1절 원가 분류', '2절 회계모형의 가격결정', '3절 대체가격', '\xa0', '\r\n\t\t\t\t2부 원가분석\r\n', '4장 이익계획', '1절 원가기획', '2절 원가추정', '3절 이익계획과 손익분기점', '5장 원가－조업도－이익분석(CVP분석)', '1절 CVP분석 개념', '2절 CVP분석 방법', '3절 CVP분석 활용', '보론 매출배합분석', '6장 관리원가', '1절 목표원가계산', '2절 품질원가계산', '3절 수명주기원가계산', '7장 예산관리', '1절 변동원가계산', '2절 종합예산', '3절 종합예산편성 사례', '\xa0', '\r\n\t\t\t\t3부 의사결정\r\n', '8장 균형성과표', '1절 균형성과표의 본질', '2절 핵심성과지표(KPI)', '3절 균형성과표 적용 사례', '9장 단기의사결정', '1절 관련원가', '2절 의사결정 방법', '3절 유형별 단기의사결정', '10장 자본예산', '1절 자본예산분석', '2절 자본예산모형', '3절 순현재가치법과 내부수익률법', '11장 불확실성 하의 의사결정', '1절 의사결정과 불확실성', '2절 불확실성 하의 의사결정기준', '3절 정보의 가치평가', '\xa0', '\r\n\t\t\t\t4부 전략적 관리회계\r\n', '12장 경제적 부가가치(EVA)', '1절 기업가치', '2절 기업가치평가', '3절 EVA 경영', '13장 책임회계와 성과평가', '1절 책임회계', '2절 책임중심점 성과평가', '3절 성과평가와 보상', '14장 관리회계분석', '1절 SWOT 분석', '2절 게임이론', '3절 협상이론', '\xa0', '\r\n\t\t\t\t부록\r\n', '<부표 1> 복리이자 요소', '<부표 2> 연금의 복리이자 요소', '<부표 3> 현가이자 요소', '<부표 4> 현금의 현가이자 요소', '<부표 5> 정규분포표', '\xa0', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4300598719', 'title': '리눅스 입문자를 위한 명령어 사전', 'price': '28,800', 'content': ['', '\r\n\t\t\t\t\tCHAPTER 1 리눅스 기본 조작법\r\n', '로그인', '데스크톱 기본 조작', '명령어 입력', '로그아웃', '셧다운', '명령어의 옵션과 인수', '도움말', '파일과 디렉터리의 개념', '파일과 디렉터리 위치', '사용자, 그룹, 권한', '\xa0', '\r\n\t\t\t\t\tCHAPTER 2 파일 다루기\r\n', '파일명 표시하기_ls\xa0', '디렉터리 작성하기_mkdir', '파일 내용 표시하기_cat', '파일 복사하기_cp\xa0', '파일 이동하기_mv', '파일명 변경하기_mv, cp', '파일 삭제하기_rm', '파일 날짜 변경하기_touch', '현재 디렉터리 표시, 변경하기_pwd, cd\xa0', '디렉터리 삭제하기_rmdir, rm\xa0', '프로그램이 존재하는 경로 표시하기_which, whereis', '터미널 출력 내용 지우기_clear', '\xa0', '\r\n\t\t\t\t\tCHAPTER 3 프로그램 관리하기\xa0\r\n', '백그라운드로 실행하기_&\xa0', '실행 중인 프로그램 정지, 종료하기_Ctrl+z, Ctrl+c', '실행 중인 프로그램 표시하기_jobs', '포그라운드로 실행하기_fg', '정지한 프로그램을 백그라운드로 재개하기_bg\xa0', '프로세스 상태 표시하기_ps\xa0', '프로그램 종료하기_kill, killall', '프로세스란\xa0', 'OS 프로세스 관리\xa0', '프로세스 부모 자식 관계\xa0', '스레드와 프로세스 관계\xa0', '사용자와 프로세스 제어\xa0', '우선 순위를 변경해서 프로그램 실행하기_nice\xa0', '특정 시간만큼 재우기_sleep\xa0', '지정한 시각마다 명령어 실행하기_crontab', '\xa0', '\r\n\t\t\t\t\tCHAPTER 4 사용자·시스템 정보 표시, 변경하기\r\n', '현재 시각 표시, 변경하기_date\xa0', '달력 표시하기_cal\xa0', '사용자 정보 표시하기_whoami, groups, id\xa0', '로그인한 사용자 정보를 표시하기_w\xa0', '암호 변경하기_passwd\xa0', '디스크 용량, 사용량 표시하기_df, du\xa0', '사용자 로그인 이력 표시하기_last\xa0', '시스템 가동 시간 표시하기_uptime\xa0', '시스템 정보 표시하기_uname\xa0', '\xa0', '\r\n\t\t\t\t\tCHAPTER 5 파일 다루기 고급편\r\n', '긴 파일 내용 표시하기_more, less\xa0', '파일 앞부분 표시하기_head\xa0', '파일 끝부분 표시하기_tail', '파일 정렬하기_sort\xa0', '중복 내용을 제거해서 표시하기_uniq\xa0', '파일 내 문자열 검색하기_grep\xa0', '텍스트 파일 길이 조사하기_wc', '두 파일 차이점 찾기_diff\xa0', '파일 소유자, 소속 그룹 변경하기_chown, chgrp', '파일 권한 변경하기_chmod\xa0', '파일 압축하고 풀기_gzip, gunzip, bzip2, bunzip2, xz, unxz\xa0', '압축 파일 내용 출력하기_zcat, bzcat, xzcat\xa0', '파일 묶고 풀기_tar\xa0', '파일에 별명 붙이기_ln\xa0', '파일 찾기_find\xa0', '파일 문자 코드 변경하기_iconv\xa0', '\xa0', '\r\n\t\t\t\t\tCHAPTER 6 편리한 명령어 사용법\r\n', '표준 입력, 표준 출력, 표준 에러 출력\xa0', '명령어 입출력을 파일로 전환하기_<,>,>>,>&', '두 명령어 조합하기_|, |&\xa0', '파일과 화면 양쪽에 출력하기_tee', '표준 입력에서 인수를 받아서 실행하기_xargs\xa0', '명령어 연달아 실행하기_;\xa0', '\r\n\t\t\t\t\t\r\n', '\r\n\t\t\t\t\tCHAPTER 7 셸과 셸 스크립트 능숙하게 다루기\r\n', '셸이란 무엇인가\xa0', '명령줄 편집하기\xa0', '명령줄 자동 완성', '여러 파일과 디렉터리 동시에 조작하기\xa0', '과거에 실행한 명령어 다시 이용하기\xa0', '명령어 이력 일괄 표시_history\xa0', '명령어에 단축어 지정하기_alias, unalias', '명령어 종류 알아보기_type\xa0', '셸 변수와 환경 변수\xa0', '변숫값 표시하기_echo\xa0', '셸 변수 표시하기_declare', '환경 변수 표시하기_printenv\xa0', '셸 변수에 값 설정하기_=, unset\xa0', '환경 변수 설정하기_export, env', '셸 설정 파일 읽기_source\xa0', '셸 스크립트\xa0', '셸 스크립트에서 변수 사용하기\xa0', '셸에서 조건 판정하기_if, case, [, test\xa0', '셸에서 반복 처리하기, 반복 처리할 숫자 나열 작성하기_for, seq\xa0', '셸에서 반복 처리하기, 다양한 연산하기_while, expr\xa0', '셸 스크립트 옵션 처리하기_getopts\xa0', '셸에서 함수 사용하기\xa0', '소수점 연산하기_bc\xa0', '텍스트 처리하기_sed\xa0', '텍스트에서 데이터 추출하기_awk\xa0', '\xa0', '\r\n\t\t\t\t\tCHAPTER 8 사용자와 시스템 관리하기\r\n', '슈퍼유저로 변신하기_su\xa0', '다른 사용자 권한으로 명령어 실행하기_sudo\xa0', '사용자 작성, 삭제하기_useradd, userdel\xa0', '그룹 작성, 삭제하기_groupadd, groupdel', '사용자, 그룹 목록 표시하기_getent\xa0', '시스템 메시지 표시하기_dmesg', '서비스 설정, 상태 표시하기_service, systemctl\xa0', '시스템 정지, 다시 시작_shutdown, reboot, poweroff\xa0', '\xa0', '\r\n\t\t\t\t\tCHAPTER 9 네트워크 능숙하게 다루기\r\n', '리눅스에서 네트워크 접속하기\xa0', '호스트와 접속 확인하기_ping\xa0', '원격 호스트를 향한 패킷 경로 표시하기_tracepath, traceroute\xa0', '호스트 IP 주소, 도메인명 검색하기_host\xa0', 'DNS 정보 검색하기_dig\xa0', '도메인 정보 취득하기_whois\xa0', '안전하게 원격 호스트 로그인하기_ssh\xa0', '지정한 URL 다운로드하기_wget, curl\xa0', '파일 전송하기_ftp, lftp\xa0', '안전하게 파일 전송하기_scp, sftp\xa0', '네트워크 인터페이스 확인, 설정하기_ip addr, ifconfig, nmcli', '인터넷 경로 설정하기_ip route, route\xa0', '네트워크 소켓 정보, 접속 상황 표시하기_ss, ip link, netstat\xa0', '네트워크 인터페이스 트래픽 데이터 표시하기_tcpdump\xa0', '네트워크 서비스 확인하기_telnet\xa0', '\xa0', '\r\n\t\t\t\t\tCHAPTER 10 파일 시스템 능숙하게 다루기\r\n', '파일 시스템과 저장 장치\xa0', '파티션\xa0', '파일 시스템 마운트하기_mount, umount\xa0', '파티션 작성하기_parted\xa0', '파일 시스템 초기화하기_mkfs\xa0', '파일 시스템 검사하기_fsck\xa0', 'USB 디바이스 정보 확인하기_lsusb\xa0', '\xa0', '\r\n\t\t\t\t\tCHAPTER 11 패키지 설치하기\r\n', '애플리케이션 추가, 관리하기(우분투, 데비안)_apt-get, apt-cache, dpkg', '애플리케이션 추가, 관리하기(CentOS, 페도라)_dnf, rpm\xa0', '\xa0', '\r\n\t\t\t\t\t부록 ema ...
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B9108907099', 'title': '파타고니아 이야기', 'price': '49,500', 'content': ['', '들어가며\xa0', '\r\n\t\t\t\t요세미티 계곡 노스 아메리카 벽\r\n', '모험을 즐기면서 얻은 교훈', '서던캘리포니아 매사냥 클럽', '1950년대의 등반과 서핑 문화', '\xa0', '\r\n\t\t\t\t요세미티 계곡 커시드럴 락\r\n', '데이브 크래프트와 앤 크래프트에게', '대폭풍우의 추억', '장인의 견습생', '에디스카벨산 북벽', '쿼터돔, 노스페이스', '\xa0', '\r\n\t\t\t\t캘리포니아 주 요세미티 계곡\r\n', '요세미티 등반의 최근 동향', '센티넬록: 새로운 북벽 인공 등반 루트', '노스아메리카월에서 남긴 개인 기록', '엘캐피탄산 뮤어월', '카이저산맥 등반에 관한 단상', '피츠로이 베이스캠프에서 맬린다 페노여에게 보내는 편지', '\xa0', '\r\n\t\t\t\t파타고니아\r\n', '즐거운 인생', '\xa0', '\r\n\t\t\t\t더그 톰킨스\r\n', '쿤야드의 불한당들', '켄 윌슨에게 보내는 편지', '\xa0', '\r\n\t\t\t\t파타고니아 플라밍고\r\n', '그때 그 텐트', '머리끈을 매고', '딕 포널을 추모하며', '반짝이는 모든 것은 금이 아니다', '쿤야드의 불한당들2-미국의 실태', '빠져나갈 수 있다', '⟪빙벽 등반⟫에서 발췌', '얼음 위의 삶: 주도성, 과감함, 균형', '\xa0', '\r\n\t\t\t\t네브래스카 주 샌드 힐 두루미\r\n', '선 철학의 가르침', '⟪글렌 엑숨⟫서문', '어머니에게', '사소한 진화: 완벽한 텔레마크 턴을 위한 201센티미터 위의 세계일주', '파우더 눈의 신화', '\xa0', '\r\n\t\t\t\t칠레 남부 피오르도 데 라스 몬타냐스\r\n', '클락스포크계곡 편도 여행', '오피히맨과 못다 한 이야기', '비장의 무기', '삿갓조개 학살자의 공격\xa0', '서커피시 부침', '해초 샐러드', '미끼를 먹자!', '플랫록의 운수 나쁜 날', '⟪세상에 나쁜 파도는 없다⟫추천사', '환초맨과 함께한 또 다른 모험: 바다와 육지를 떠돈 한 달의 기록', '무리', '클레어에게', '캘커타의 기적', '미네스트로네 부화장', '브루스 힐을 위한 추도 연설', '부탄 브라운송어: 날도래 출현 주의', '더그 톰킨스, 우리의 마지막 대장', '\xa0', '\r\n\t\t\t\t칠레 인엑스플로라도 호수 수원지\r\n', '시간을 헤아리다', '\xa0', '\r\n\t\t\t\t바하마 제도 여울멸 낚시\r\n', '허탕의 이유', '심플 플라이 낚시에서 얻은 교훈', '\xa0', '\r\n\t\t\t\t부화장에서 태어난 샌프란시스코 베이로 방류되는 물고기\r\n', '냉수성어업을 위협하는 요인들', '브리티시 컬럼비아 주 바다늑대', '투표가 시간 낭비가 아닌 이유', '대통령께', '도구 컨퍼런스를 여는 이유', '\xa0', '\r\n\t\t\t\t워싱턴 D.C에 모인 12,000명의 젊은 유권자들\r\n', '리스판서블 경제', '선한 일을 하라', '\xa0', '우리별지구', '\xa0', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7015117381', 'title': '풀스택 서버리스 :  리액트, AWS, 그래프QL을 이용한 최신 애플리케이션 개발', 'price': '18,900', 'content': ['', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20021 서버리스 컴퓨팅 시대의 풀스택 개발\r\n', '1.1 현대적인 서버리스 철학', '1.2 AWS 소개', '1.3 AWS Amplify CLI 소개', '1.4 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20022 AWS Amplify 시작하기\r\n', '2.1 서버리스 함수 생성과 배포', '2.2 API 추가', '2.3 새 API와 통신', '2.4 다른 API를 호출하도록 함수 수정', '2.5 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20023 첫 번째 애플리케이션 만들기\r\n', '3.1 그래프QL 소개', '3.2 그래프QL API 생성', '3.3 그래프QL API와 통신 및 확인', '3.4 리액트 애플리케이션 구축', '3.5 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20024 인증 소개\r\n', '4.1 Amazon Cognito 소개', '4.2 리액트 애플리케이션 생성과 Amplify 추가', '4.3 애플리케이션 빌드', '4.4 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20025 사용자 정의 인증 전략\r\n', '5.1 protectedRoute Hook 만들기', '5.2 Form 컴포넌트 만들기', '5.3 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20026 서버리스 함수 심화 1\r\n', '6.1 이벤트 소스와 데이터 구조', '6.2 IAM 권한 및 트리거 설정', '6.3 기본 프로젝트 생성', '6.4 Post Confirmation Lambda Trigger 추가', '6.5 AWS Lambda와 Amazon S3를 이용한 동적 이미지 크기 조정', '6.6 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20027 서버리스 함수 심화 2\r\n', '7.1 구축할 애플리케이션', '7.2 시작하기', '7.3 인증 및 그룹 권한 추가', '7.4 데이터베이스 추가', '7.5 API 추가', '7.6 프런트엔드 만들기', '7.7 애플리케이션 테스트', '7.8 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20028 AWS AppSync 심화\r\n', '8.1 그래프QL, AppSync API 및 React Router', '8.2 애플리케이션 구축 시작하기', '8.3 Amplify 프로젝트 생성', '8.4 백엔드 구축', '8.5 서비스 배포', '8.6 프런트엔드 구축', '8.7 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u20029 Amplify DataStore를 이용한 오프라인 애플리케이션 구축\r\n', '9.1 Amplify DataStore란?', '9.2 Amplify DataStore를 이용한 실시간 애플리케이션 구축', '9.3 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u200210 이미지와 스토리지 작업\r\n', '10.1 Amazon S3', '10.2 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\t\t\tchapter\u200211 호스팅: CI/CD를 이용한 애플리케이션 배포\r\n', '11.1 CLI 기반 배포', '11.2 깃 기반 배포', '11.3 액세스 제어', '11.4 사용자 지정 도메인', '11.5 마치며\xa0']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7448632539', 'title': '한 권으로 배우는 작고 예쁜 꽃자수', 'price': '16,200', 'content': ['', '프롤로그', '이 책을 보는 방법', '\xa0', '\r\n\t\t\t\tBasic. 꽃자수와 친해지는 시간\r\n', '1 꽃자수를 위한 준비물', '2 꽃자수 준비하기', '3 꽃자수 표현하기', '\xa0', '\r\n\t\t\t\tPart 1. 차근차근 익히는 시간\r\n', '1 꽃을 만드는 스티치', '2 잎을 만드는 스티치', '3 줄기를 만드는 스티치', '4 꽃을 꾸미는 스티치', '5 스티치 연습', '\xa0', '\r\n\t\t\t\tPart 2. 꽃을 수놓는 시간\r\n', '\r\n\t\t\t\t1 보라색과 파란색 꽃\r\n', '라벤더(응용: 라벤더 리스)', '블루스타', '나비수국', '클레마티스', '\xa0', '\r\n\t\t\t\t2 노란색과 주황색 꽃\r\n', '해바라기(응용: 해바라기 패턴)', '유채꽃', '아이슬란드 포피', '아이슬란드 포피 꽃병', '개나리', '\xa0', '\r\n\t\t\t\t3 분홍색 꽃\r\n', '사과꽃', '매화', '벚꽃', '소국', '\xa0', '\r\n\t\t\t\t4 빨간색 꽃\r\n', '동백(응용: 카멜리아힐 동백)', '채송화', '꽃양귀비', '카네이션', '\xa0', '\r\n\t\t\t\t5 흰색 꽃\r\n', '스노우드롭', '토끼풀', '백합', '왁스플라워', '\xa0', '\r\n\t\t\t\t6 특별한 색상 조합\r\n', '네 가지 화분(응용: 히야신스 화분)', '가을 꽃수레(응용: 봄날 꽃수레)', '핼러윈 호박', '크리스마스 꽃다발(응용: 크리스마스 리스, 크리스마스 트리)', '\xa0', '부록 | 실물 크기 도안']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B3148701816', 'title': 'IT CookBook, 처음 만나는 회로이론(2판)', 'price': '23,000', 'content': ['', '\r\n\t\t\t\t\t\tCHAPTER 01 회로의 기초\r\n', 'SECTION 1.1 회로 소자\xa0 \xa0 \xa0\xa0', 'SECTION 1.2 회로 설계의 이해\xa0 \xa0 \xa0 \xa0 \xa0\xa0', 'SECTION 1.3 등가 저항과 개방/단락 회로\xa0 \xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 02 회로 해석의 다양한 방법\r\n', 'SECTION 2.1 전압과 전류 분할 법칙\xa0 \xa0 \xa0\xa0', 'SECTION 2.2 핵심 회로 해석 방법\xa0 \xa0 \xa0 \xa0 \xa0', 'SECTION 2.3 테브난과 노턴 등가 회로\xa0 \xa0\xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 03 커패시터와 인덕터\r\n', 'SECTION 3.1 커패시터', 'SECTION 3.2 커패시터의 연결\xa0 \xa0 \xa0\xa0', 'SECTION 3.3 인덕터', 'SECTION 3.4 인덕터의 연결\xa0 \xa0 \xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 04 회로 해석을 위한 기본 수학\r\n', 'SECTION 4.1 선형방정식\xa0 \xa0 \xa0', 'SECTION 4.2 미분방정식\xa0 \xa0 \xa0', 'SECTION 4.3 복소수\xa0 \xa0 \xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 05 1차 회로와 2차 회로\r\n', 'SECTION 5.1 1차 회로\xa0 \xa0 \xa0', 'SECTION 5.2 2차 회로\xa0 \xa0 \xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 06 교류 회로\xa0\r\n', 'SECTION 6.1 정현파 신호\xa0 \xa0 \xa0', 'SECTION 6.2 교류 해석을 위한 푸리에 정리\xa0 \xa0', 'SECTION 6.3 위상벡터\xa0 \xa0 \xa0', 'SECTION 6.4 수동 소자의 임피던스\xa0 \xa0 \xa0 \xa0', 'SECTION 6.5 교류 회로의 분석\xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 07 교류 회로의 전력\r\n', 'SECTION 7.1 교류 회로의 전력\xa0 \xa0\xa0', 'SECTION 7.2 3상 전력\xa0 \xa0 \xa0', 'SECTION 7.3 평형 3상 시스템\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 08 주파수 응답\r\n', 'SECTION 8.1 주파수 응답과 전달함수\xa0 \xa0\xa0', 'SECTION 8.2 공진 주파수\xa0 \xa0 \xa0', 'SECTION 8.3 주파수 범위에 따른 필터 종류\xa0 \xa0', 'SECTION 8.4 시각적인 주파수 응답 해석 방법\xa0 \xa0', '연습문제\xa0 \xa0 \xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 09 라플라스 변환을 이용한 회로 해석\r\n', 'SECTION 9.1 라플라스 변환과 역변환\xa0 \xa0\xa0', 'SECTION 9.2 라플라스 변환의 기본 특성\xa0\xa0', 'SECTION 9.3 라플라스 영역의 회로 소자 및 전달함수', 'SECTION 9.4 라플라스 영역의 회로 해석\xa0 \xa0', '연습문제\xa0']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2591303726', 'title': '안전필수 시스템 제어 설계', 'price': '38,000', 'content': ['', '\r\n\t\t\t\t\t\t\t[들어가기 전에] 제어시스템 개요\r\n', '0.1 제어공학에 대한 기본 이해', '0.2 시나리오로 풀어보는 제어공학의 이슈들', '0.3 신호와 시스템 이해하기', '0.4 제어 대상의 모델링', '0.5 이산신호의 시계열신호 처리 방법', '0.6 제어시스템 설계\xa0', '0.7 제어기 설계 연습(PID)', '0.8 현대제어 이론', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tPART 1 _ 제어시스템 RAMS\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\t\t1장. 안전필수 시스템의 제어특성\r\n', '1.1 안전필수 시스템', '1.2 안전필수 시스템 제어시스템의 지향점', '1.3 시나리오로 풀어보는 다중화 설계와 고장진단', '생각해보기', '\xa0', '\r\n\t\t\t\t\t\t\t2장. 제어시스템의 고장과 고장허용설계\r\n', '2.1 fault, error, fail', '2.2 fault, error, fail의 공학적 구분', '생각해보기', '\xa0', '\r\n\t\t\t\t\t\t\t3장. RAMS 이론과 분석 방법\r\n', '3.1 확률변수와 고장률', '3.2 신뢰도와 고장률', '3.3 가용도와 유지보수도', '3.4 안전도', '3.5 신뢰도 계산 모형\xa0', '3.6 마코프 모델\xa0', '생각해보기', '\xa0', '\r\n\t\t\t\t\t\t\t4장. 안전필수 시스템의 제어설계 과정\r\n', '4.1 안전관련 제어시스템의 일반 사항', '4.2 안전관련 제어시스템 설계 요건', '4.3 고장모드 및 영향 분석', '4.4 고장나무분석(FTA)', '4.5 마코프 모델링 상세\xa0', '4.6 안전필수 제어시스템 설계 실무', '\xa0', '현장의 목소리 #01', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tPART 2 _ 제어시스템 설계와 소프트웨어 개발\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\t\t5장. 원전 MMIS와 전기 1등급 PLC\r\n', '5.1 원전 MMIS\xa0', '5.2 전기 1등급 PLC: POSAFE-Q\xa0', '5.3 MMIS 확인검증 과정', '\xa0', '\r\n\t\t\t\t\t\t\t6장. TMR 디지털 여자시스템 설계와 분석\r\n', '6.1 발전기와 여자시스템 소개', '6.2 기능구현과 설계검증', '6.3 RAMS 비교 분석(삼중화 여자시스템)', '생각해보기', '\xa0', '\r\n\t\t\t\t\t\t\t7장. 안전필수 소프트웨어 개발 방법론\r\n', '7.1 안전필수 소프트웨어 개발 방법론\xa0', '7.2 소프트웨어 요구사항', '7.3 소프트웨어 설계\xa0', '7.4 소프트웨어 구현\xa0', '7.5 사이버 보안', '7.6 안전필수 소프트웨어 개발', '생각해보기', '\xa0', '\r\n\t\t\t\t\t\t\t8장. 소프트웨어 확인 및 검증 방법론과 사례\r\n', '8.1 소프트웨어 확인 및 검증 방법론', '8.2 소프트웨어 요구사항 및 설계 문서 검증\xa0', '8.3 소프트웨어 구현 검증', '8.4 소프트웨어 테스팅\xa0', '생각해보기', '\xa0', '현장의 목소리 #02', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tPART 3 _ 제어시스템 하드웨어 건전성\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\t\t9장. 품질보증과 관리\r\n', '9.1 서론', '9.2 품질 시스템의 필요성', '9.3 품질체계', '9.4 품질활동', '9.5 품질보증 시스템', '생각해보기', '\xa0', '\r\n\t\t\t\t\t\t\t10장. 기기검증 시험\r\n', '10.1 생활 속의 기기검증', '10.2 기기검증이란', '10.3 기기검증 수행', '10.4 일반규격품의 품질검증(CGID)', '10.5 문서화', '10.6 인증', '생각해보기', '\xa0', '\r\n\t\t\t\t\t\t\t11장. 인간공학\r\n', '11.1 서론\xa0', '11.2 인간공학과 시스템 설계\xa0', '11.3 인간공학 설계 검토 및 규제 기준', '11.4 인간공학 설계 예']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B9602652686', 'title': '데이터 스토리', 'price': '19,800', 'content': ['', '들어가며', '__ 스토리텔링의 효과 알아보기', '__ 숫자를 이야기로 바꾸기', '__ 데이터로 소통 주도하기', '__ 소통 역량에 투자하기', '__ 이야기의 힘을 내 것으로 만들기', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tPART 1 데이터로 소통하기\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 01 데이터로 소통하는 사람 되기\r\n', '__ 데이터로 소통하는 능력 기르기', '__ 스토리텔링으로 데이터 설명하기', '__ 데이터로 주변 사람들을 도와주는 멘토 되기\xa0', '__ 데이터로 문제 해결의 기회 포착하기', '__ 데이터 앞에서 창의적으로 사고하기', '__ 직관력 기르기', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 02 의사결정자와 소통하기\r\n', '__ 의사결정자 파악하기', '__ 경영자의 시간을 배려하는 소통하기', '__ 경영자가 성과를 평가받는 방법 이해하기\xa0', '__ 경영자의 정보 습득 방식 이해하기', '__ 끼어들기와 질문에 대비하기', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tPART 2 잘 짜여진 스토리로 정확하게 의사전달하기\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 03 데이터 관점 만들기\r\n', '__ 자신만의 데이터 관점 만들기\xa0', '__ 성공한 제안의 어휘 패턴 이해하기\xa0', '__ 데이터 관점을 전달할 때 가장 효과적인 동사 선택하기\xa0', '__ 성과 동사와 과정 동사 활용하기', '__ 전략적 통찰을 기반으로 행동 구상하기\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 04 데이터 스토리 형식으로 요약 보고서 만들기\r\n', '__ 이야기 구조 활용하기\xa0', '__ 3막 구조로 요약 보고서 작성하기\xa0', '__ 2막에서 얽히고설킨 상황 해결하기\xa0', '__ 3막에는 데이터 관점 사용하기\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 05 분석을 통해 행동 유도하기\r\n', '__ 논리적이고 설득력 있는 글쓰기\xa0', '__ 제안 나무 구조 활용하기', '__ 데이터 스토리를 뒷받침할 행동 정의하기', '__ 이유를 제시해서 동기 부여하기', '__ 회의적으로 생각하기\xa0', '__ 미래 상황 가정하기', '__ 제안 나무 구조의 구성 요소 검토하기\xa0', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tPART 3 명료한 차트와 한눈에 들어오는 슬라이드 만들기\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 06 상황에 맞는 차트 선택과 설명글 작성하기\r\n', '__ 이해가 잘되는 차트 사용하기\xa0', '__ 깔끔한 차트 제목 작성하기\xa0', "__ ‘설명하듯' 설명글 작성하기\xa0", '__ 형용사로 막대 차트의 규모 설명하기\xa0', '__ 형용사로 성분 차트의 비율 설명하기\xa0', '__ 부사를 사용해 선 차트 추세 설명하기\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 07 시각 요소로 차트 가독성 높이기\r\n', '__ 차트에 시각적 설명 요소 더하기', '__ 중요한 데이터를 돋보이게 표현하기', '__ 중요한 데이터에 수치 정보 더하기', '__ 통찰을 시각적으로 전달하기\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 08 핵심이 한눈에 들어오는 슬라이드 만들기\r\n', '__ 제안용 슬라이드 문서 만들기\xa0', '__ 슬라이드 문서를 실용서라고 생각하기\xa0', '__ 쉽게 읽을 수 있도록 구성하기\xa0', '__ 기본 서식을 탈피해 핵심 내용 강조하기\xa0', '__ 중요한 텍스트 강조하기\xa0', '__ 제안 나무 구조 점검하기\xa0', '__ 제안 나무 구조의 슬라이드 문서 검토하기\xa0', '\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tPART 4 실전! 데이터 활용하기\r\n', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 09 규모로 보여주기\r\n', '__ 익숙한 대상과 데이터 비교하기', '__ 규모에 대한 감각 키우기', '__ 익숙한 크기와 데이터 연결하기', '__ 익숙한 시간 단위와 데이터 연결하기\xa0', '__ 익숙한 사물과 데이터 비교하기\xa0', '__ 데이터에 대한 감정 표현하기', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 10 데이터 의인화하기\r\n', '__ 데이터 세계의 영웅과 악당\xa0', '__ 데이터 속 악당 파악하기\xa0', '__ 데이터 속 갈등 해결하기\xa0', '__ 등장인물과 대화하기\xa0', '__ 데이터에 의미 부여하기\xa0', '|사례연구| “데이터로 생명을 구하다"', '\xa0', '\r\n\t\t\t\t\t\t\t\t\t\tCHAPTER 11 데이터를 활용한 스토리텔링\r\n', '__ 시간차로 데이터 제시하기\xa0', '__ 숨은 데이터 드러내기', '|사례연구| “데이터의 극대화를 위해 도구를 사용하다"\xa0', '|사례연구| “감정 곡선으로 이야기를 만들다”\xa0', '__ 감정 곡선으로 데이터 스토리텔링 하기\xa0', '|사례연구| “신데렐라 곡선으로 불운을 뒤집다"\xa0', '|사례연구| “데이터에 맥락을 곁들여 이야기하다”', '\xa0', '부록\xa0', '__ 부록 A. 3막 구조에 활용 가능한 다양한 접속사\xa0', '__ 부록 B. 의사결정 속도를 높여주는 원 페이지 요약 보고서 예시', '__ 부록 C. 시각 요소 샘플 다운로드', '__ 참고자료', '\xa0', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7468885216', 'title': '러닝 리액트(2판)', 'price': '25,200', 'content': ['', '\r\n\t\t\t\t\t\t\t\tCHAPTER 1 리액트 소개\r\n', '1.1 튼튼한 토대', '1.2 리액트의 과거와 미래', '1.3 코드 예제 사용법', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 2 리액트를 위한 자바스크립트\r\n', '2.1 변수 선언하기', '2.2 함수 만들기', '2.3 자바스크립트 컴파일하기', '2.4 객체와 배열', '2.5 비동기 자바스크립트', '2.6 클래스', '2.7 ES6 모듈', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 3 자바스크립트를 활용한 함수형 프로그래밍\r\n', '3.1 함수형이란 무엇인가?', '3.2 명령형 프로그래밍과 선언적 프로그래밍 비교', '3.3 함수형 프로그래밍의 개념', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 4 리액트의 작동 원리\r\n', '4.1 페이지 설정', '4.2 리액트 엘리먼트', '4.3 ReactDOM', '4.4 리액트 컴포넌트', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 5 JSX를 사용하는 리액트\r\n', '5.1 JSX로 리액트 엘리먼트 정의하기', '5.2 바벨', '5.3 JSX로 작성한 조리법', '5.4 리액트 프래그먼트', '5.5 웹팩 소개', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 6 리액트 상태 관리\r\n', '6.1 별점 컴포넌트 만들기', '6.2 useState 훅', '6.3 재사용성을 높이기 위한 리팩터링', '6.4 컴포넌트 트리 안의 상태', '6.5 폼 만들기', '6.6 리액트 콘텍스트', '\r\n\t\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\t\t\tCHAPTER 7 훅스로 컴포넌트 개선하기\r\n', '7.1 useEffect 소개', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 8 데이터 포함시키기\r\n', '8.1 데이터 요청하기', '8.2 렌더 프롭', '8.3 가상화된 리스트', '8.4 GraphQL 소개', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 9 Suspense\r\n', '9.1 오류 경계', '9.2 코드 분리하기', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 10 리액트 테스트\r\n', '10.2 프리티어.10.3 리액트 애플리케이션을 위한 타입 검사', '10.4 테스트 주도 개발', '10.5 제스트 사용하기', '10.6 리액트 컴포넌트 테스트하기', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 11 리액트 라우터\r\n', '11.1 라우터 사용하기', '11.2 라우터 프로퍼티', '11.3 리디렉션 사용하기', '\xa0', '\r\n\t\t\t\t\t\t\t\tCHAPTER 12 리액트와 서버\r\n', '12.1 아이소모피즘과 유니버설리즘 비교', '12.2 서버 렌더링 리액트', '12.3 넥스트.js를 사용한 서버 렌더링', '12.4 개츠비', '12.5 리액트의 미래']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1108557246', 'title': '상식의 재구성', 'price': '19,800', 'content': ['', '이 책을 읽는 독자를 위한 독법 가이드', '프롤로그 2020 전 세계 코로나 일제고사', '1장 불평등 퍼즐', '2장 미디어 유토피아 디스토피아', '3장 민주주의 멀미', '4장 독일의 경우', '5장 이념 트라우마', '6장 일본 딜레마', '7장 한국인은 누구인가', '책을 마치며']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B9354330938', 'title': '업무에 바로 쓰는 SQL 튜닝', 'price': '19,800', 'content': ['', '\r\n\t\t\t\t\t\t\t1장. MySQL과 MariaDB 개요\r\n', '1.1 현황', '1.2 상용 RDBMS와의 차이점', '1.3 MySQL과 MariaDB 튜닝의 중요성', '1.4 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t2장. SQL 튜닝 용어를 직관적으로 이해하기\r\n', '2.1 물리 엔진과 오브젝트 용어', '2.2 논리적인 SQL\xa0 개념 용어', '2.3 개념적인 튜닝 용어', '2.4 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t3장. SQL 튜닝의 실행 계획 파헤치기\r\n', '3.1 실습 환경 구성하기', '3.2 실행 계획 수행', '3.3 프로파일링', '3.4 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t4장. 악성 SQL 튜닝으로 초보자 탈출하기\r\n', '4.1 SQL 튜닝 준비하기', '4.2 SQL 문 단순 수정으로 착한 쿼리 만들기', '4.3 테이블 조인 설정 변경으로 착한 쿼리 만들기', '4.4 마치며', '\xa0', '\r\n\t\t\t\t\t\t\t5장. 악성 SQL 튜닝으로 전문가 되기\r\n', '5.1 SQL 문 재작성으로 착한 쿼리 만들', '5.2 인덱스 조정으로 착한 쿼리 만들기', '5.3 적절한 테이블 및 열 속성 설정으로 착한 쿼리 만들기', '5.4 마치며']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B3006151946', 'title': 'IT CookBook, C로 배우는 쉬운 자료구조 4판', 'price': '29,000', 'content': ['', '\r\n\t\t\t\t\t\t\t\t\tChapter 01 자료구조 소개\r\n', '01 자료구조의 이해\xa0', '02 자료의 표현\xa0', '03 자료의 추상화\xa0', '04 알고리즘의 이해\xa0', '05 알고리즘의 표현 방법\xa0', '06 알고리즘의 성능 분석\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 02 자료구조 구현을 위한 C 프로그래밍 기법\r\n', '01 배열\xa0', '02 포인터\xa0', '03 구조체\xa0', '04 재귀호출\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 03 순차 자료구조와 선형 리스트\r\n', '01 순차 자료구조와 선형 리스트의 이해\xa0', '02 선형 리스트의 연산과 알고리즘\xa0', '03 선형 리스트의 응용 및 구현\xa0', '응용예제\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 04 연결 자료구조와 연결 리스트\r\n', '01 연결 자료구조와 연결 리스트의 이해\xa0', '02 단순 연결 리스트\xa0', '03 원형 연결 리스트\xa0', '04 이중 연결 리스트\xa0', '05 연결 리스트의 응용 및 구현\xa0', '응용예제\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 05 스택\r\n', '01 스택의 이해\xa0', '02 스택의 구현\xa0', '03 스택의 응용\xa0', '응용예제\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 06 큐\r\n', '01 큐의 이해\xa0', '02 큐의 구현\xa0', '03 데크\xa0', '04 큐의 응용\xa0', '응용예제\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 07 트리\r\n', '01 트리의 이해\xa0', '02 이진 트리\xa0', '03 이진 트리의 구현\xa0', '04 이진 트리의 순회\xa0', '05 이진 탐색 트리\xa0', '06 균형 이진 탐색 트리\xa0', '07 히프의 개념과 연산 및 구현\xa0', '응용예제\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 08 그래프\r\n', '01 그래프의 구조\xa0', '02 그래프의 구현\xa0', '03 그래프의 순회\xa0', '04 신장 트리와 최소 비용 신장 트리\xa0', '응용예제\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 09 정렬\r\n', '01 정렬의 이해\xa0', '02 선택 정렬\xa0', '03 버블 정렬\xa0', '04 퀵 정렬\xa0', '05 삽입 정렬\xa0', '06 셸 정렬\xa0', '07 병합 정렬\xa0', '08 기수 정렬\xa0', '09 히프 정렬\xa0', '10 트리 정렬\xa0', '응용예제\xa0', '요약 / 연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\t\t\tChapter 10 검색\r\n', '01 검색의 이해\xa0', '02 순차 검색\xa0', '03 이진 검색\xa0', '04 이진 트리 검색\xa0', '05 해싱\xa0', '응용예제\xa0', '요약 / 연습문제']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B2388883228', 'title': 'IT CookBook, 디지털 콘텐츠 기획(2판)', 'price': '30,000', 'content': ['', '\r\n\t\t\t\t\t\tPART 01 디지털 콘텐츠와 디지털 매체\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 01 디지털 콘텐츠 기획의 개요\r\n', '01 디지털 콘텐츠', '02 디지털 콘텐츠 기획', '03 디지털 콘텐츠 기획자', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 02 디지털 매체의 진화\r\n', '01 월드와이드웹', '02 데스크톱 컴퓨터', '03 스마트폰', '04 키오스크', '05 디지털 사이니지', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 03 디지털 사회와 커뮤니케이션\r\n', '01 소셜 네트워크 서비스', '02 영상 기반의 스트리밍 플랫폼', '03 OTT 서비스', '04 넥스트 패러다임', '요약', '실습과제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 02 요구 분석 및 사용자 정의\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 04 요구 분석\r\n', '01 요구 분석의 이해', '02 요구사항 정의', '03 요구사항 우선순위 체크리스트', '04 요구사항 핵심 파악', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 05 의견 조율\r\n', '01 커뮤니케이션 및 회의 진행', '02 아이스브레이킹', '03 브레인스토밍', '04 브레인라이팅', '05 회의록 작성', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 06 사용자 정의\r\n', '01 사용자 분석', '02 인터뷰', '03 에스노그래피 조사', '04 페르소나 모형', '요약', '실습과제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 03 환경 분석\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 07 정보 수집\r\n', '01 정보 수집의 의해', '02 동향 파악 및 분석', '03 동향 사이클 및 상관관계 분석', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 08 시장 환경 분석\r\n', '01 거시 환경 분석', '02 미시 환경 분석', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 09 프로젝트 환경 분석 및 조사 보고서 작성\r\n', '01 프로젝트 환경 분석의 이해', '02 기술적 환경 분석', '03 내부 환경 분석', '04 예산 및 일정 수립', '05 조사 보고서 작성', '요약', '실습과제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 04 디자인 방향성 정의\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 10 콘셉트 수립 및 차별화 전략\r\n', '01 디자인 요구사항 및 사용자 성향 분석', '02 기능적 요구사항 및 디자인 제약 조건 파악', '03 콘셉트 수립', '04 마인드 맵핑', '05 벤치마킹', '06 마케팅 포지셔닝', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 11 콘셉트 시각화\r\n', '01 콘셉트 시각화의 이해', '02 핵시 키워드 도출', '03 콘셉트 시각화 표현', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 12 톤&매너 설정\r\n', '01 톤&매너 설정의 이해', '02 색채 이미지 공간', '요약', '실습과제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 05 시나리오 작성 및 정보구조 설계\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 13 시나리오 기획 및 작성\r\n', '01 시나리오 기획', '02 시나리오 작성', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 14 정보구조 설계\r\n', '\r\n\t\t\t\t\t\t01 정보구조 설계의 이해\t\t\r\n', '02 정보구조의 유형', '03 카드소팅', '04 레이블링', '05 내비게이션 시스템', '요약', '실습과제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 06 스토리보드 제작\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 15 와이어프레임 작성\r\n', '01 와이어프레임의 이해', '02 화면 레이아웃 구성', '03 인터페이스 설계', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 16 스토리보드 작성\r\n', '01 스토리보드의 이해', '02 서비스 흐름도', '03 스토리보드의 화면 설계', '요약', '실습과제', '\xa0', '\xa0', '\r\n\t\t\t\t\t\tPART 07 프로토타이핑&사용성 테스트\r\n', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 17 프로토타이핑\r\n', '01 프로토타이핑의 이해', '02 프로토타이핑의 종류', '03 프로토타이핑 제작 도구', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 18 사용성 테스트 개요\r\n', '01 사용성 테스트의 이해', '02 사용성 테스트의 종류', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 19 사용성 테스트 수행\r\n', '01 사용성 테스트 목표 및 이슈 정리', '02 사용성 테스트 프로세스', '요약', '실습과제', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 20 사용성 테스트 결과 분석\r\n', '01 사용성 테스트 분석', '02 사용성 테스트 결과 보고서 작성', '요약', '실습과제', '\xa0', '참고문헌', '찾아보기']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B4766499846', 'title': 'IT CookBook, 쉽게 배우는 소프트웨어 공학 2판', 'price': '30,000', 'content': ['', '\r\n\t\t\t\t\t\t\tChapter 01 소프트웨어 공학과 개발 프로세스\r\n', '01 소프트웨어의 이해\xa0', '02 소프트웨어 개발 프로세스\xa0', '03 주먹구구식 모델\xa0', '04 선형 순차적 모델\xa0', '05 진화적 프로세스 모델\xa0', '06 단계적 개발 모델\xa0', '07 통합 프로세스 모델\xa0', '08 애자일 프로세스 모델\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 02 UML\r\n', '01 UML의 이해\xa0', '02 유스케이스 다이어그램\xa0', '03 클래스 다이어그램\xa0', '04 순차 다이어그램\xa0', '05 통신 다이어그램\xa0', '06 활동 다이어그램\xa0', '07 상태 다이어그램\xa0', '08 컴포넌트 다이어그램\xa0', '09 배치 다이어그램\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 03 계획\r\n', '01 계획의 이해\xa0', '02 문제 정의\xa0', '03 타당성 분석\xa0', '04 개발 비용 산정\xa0', '05 비용 산정 기법 1: 하향식 산정 기법\xa0', '06 비용 산정 기법 2: 상향식 산정 기법\xa0', '07 비용 산정 기법 3: 수학적 산정 기법\xa0', '08 일정 계획\xa0', '09 위험 분석\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 04 요구분석\r\n', '01 요구사항\xa0', '02 요구분석의 이해\xa0', '03 요구분석 절차와 요구사항 종류\xa0', '04 요구사항의 표현\xa0', '05 요구사항의 문서화\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 05 설계\r\n', '01 설계의 이해\xa0', '02 설계의 원리\xa0', '03 모듈화\xa0', '04 사용자 인터페이스 설계\xa0', '연습문제\xa0', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\t\t\t\tChapter 06 아키텍처 설계와 클래스 설계\r\n', '01 아키텍처 설계\xa0', '02 클래스 간의 관계\xa0', '03 클래스 설계 원칙\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 07 디자인 패턴\r\n', '01 디자인 패턴의 이해\xa0', '02 행위 패턴\xa0', '03 구조 패턴\xa0', '04 생성 패턴\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 08 구현\r\n', '01 프로그래밍 언어의 역사\xa0', '02 표준 코딩 규칙의 필요성\xa0', '03 주요 표준 코딩 규칙\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 09 테스트\r\n', '01 테스트의 이해\xa0', '02 테스트의 분류\xa0', '03 정적 테스트\xa0', '04 동적 테스트\xa0', '05 소프트웨어 개발 단계에 따른 테스트\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 10 품질\r\n', '01 품질의 이해\xa0', '02 품질 요소와 품질 평가 모델\xa0', '03 제품 품질 특성 평가 모델\xa0', '04 프로세스 품질 특성 평가 모델\xa0', '05 대표적인 프로세스 능력 평가 모델\xa0', '06 품질 관리\xa0', '연습문제\xa0', '\xa0', '\r\n\t\t\t\t\t\t\tChapter 11 프로젝트 관리\r\n', '01 프로젝트의 이해\xa0', '02 프로젝트 관리의 이해\xa0', '03 형상 관리\xa0', '04 유지보수\xa0', '연습문제']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B1904486238', 'title': 'IT CookBook, 컴퓨터 구조와 원리 3.0', 'price': '29,000', 'content': ['', '\r\n\t\tChapter 01 컴퓨터의 구조\r\n', '01 컴퓨터 시스템의 구성 요소', '02 컴퓨터의 발전 과정', '03 컴퓨터의 분류', '요약/연습문제', '\xa0', '\r\n\t\tChapter 02 데이터의 표현과 연산\r\n', '01 정보의 표현 단위와 수 체계', '02 정수 표현', '03 실수 표현', '04 문자 표현', '05 2진수의 연산', '요약/연습문제', '\r\n\t\t\r\n', '\r\n\t\tChapter 03 디지털 논리\r\n', '01 논리 게이트', '02 불 대수', '03 논리식의 간략화', '04 플립플롭', '요약/연습문제', '읽을거리', '\xa0', '\r\n\t\tChapter 04 컴퓨터에서 활용되는 디지털 논리회로\r\n', '01 조합 논리회로와 순차 논리회로의 개념', '02 조합 논리회로', '03 순차 논리회로', '요약/연습문제', '\xa0', '\r\n\t\tChapter 05 컴퓨터 시스템의 구성과 기능\r\n', '01 컴퓨터의 구성 요소', '02 버스와 상호 연결', '03 컴퓨터의 기능과 동작', '요약/연습문제', '\xa0', '\r\n\t\tChapter 06 중앙 처리 장치의 구성과 기능\r\n', '01 CPU와 마이크로프로세서', '02 CPU의 내부 구조', '03 CPU의 논리회로 설계', '04 CPU의 기능, 독작, 성능', '요약/연습문제', '\xa0', '\r\n\t\tChapter 07 주기억 장치\r\n', '01 기억 장치의 개요', '02 주기억 장치', '03 RAM과 ROM', '04 기억 장치의 확장', '요약/연습문제', '\xa0', '\r\n\t\tChapter 08 캐시 기억 장치\r\n', '01 캐시 기억 장치의 개념', '02 캐시 기억 장치의 원리', '03 캐시 기억 장치의 설계', '04 캐시 기억 장치의 구조', '요약/연습문제', '\r\n\t\t\r\n', '\r\n\t\tChapter 09 보조 기억 장치\r\n', '01 보조 기억 장치의 개념', '02 자기 기억 장치', '03 광디스크 기억 장치', '04 기타 기억 장치', '요약/연습문제', '\xa0', '\r\n\t\tChapter 10 입력과 출력\r\n', '01 입력 장치와 출력 장치', '02 입출력 모듈', '03 입출력 장치의 연결과 데이터 전송', '04 입출력 제어 기법', '요약/연습문제', '\r\n\t\t\r\n', '\r\n\t\tChapter 11 시스템 버스\r\n', '01 컴퓨터 버스의 개요', '02 시스템 버스의 개념', '03 다중 버스 계층 구조', '04 버스 중재', '요약/연습문제', '\xa0', '\r\n\t\tChapter 12 중앙 처리 장치의 명령어\r\n', '01 어셈블리 프로그램', '02 명령어 사이클', '03 명령어 집합', '04 축소 명령어 집합 컴퓨터', '요약/연습문제', '\xa0', '\r\n\t\tChapter 13 효과적인 컴퓨터 명령어 실행 기법\r\n', '01 주소 지정 방식', '02 인터럽트 처리', '03 명령어 파이프라이닝', '04 슈퍼스칼라 프로세서', '요약/연습문제', '\xa0', '\r\n\t\tChapter 14 마이크로 연산과 제어 장치\r\n', '01 제어 장치의 개념', '02 마이크로 연산', '03 제어 장치 모델의 구현', '04 마이크로프로그램을 이용한 제어', '요약/연습문제', '\xa0', '\r\n\t\tChapter 15 병렬 컴퓨터 구조\r\n', '01 병렬 처리의 개념', '02 병렬 컴퓨터의 분류', '03 배열 프로세서와 다중 프로세서', '04 다중 프로세서 시스템', '요약/연습문제']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B9380943452', 'title': '찾아도 찾아도 끝판왕 1000개 숨은그림찾기 숲속 놀이터', 'price': '7,200', 'content': ['', '\xa0']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B6918140228', 'title': '찾아도 찾아도 끝판왕 1000개 숨은그림찾기 우리 동네', 'price': '7,200', 'content': ['', '\xa0']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B3573121629', 'title': '처음 배우는 네트워크 보안', 'price': '25,200', 'content': ['', '\r\n\t\t\t\t\t\tCHAPTER 1 네트워크 보안 시작\xa0\r\n', '1.1 네트워크 보안과 보안 관제 필요성\xa0', '1.2 보안 조직 구성\xa0', '1.3 보안 관제 센터 구축\xa0', '1.4 보안 관제 실무\xa0', '1.5 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 2 네트워크 보안 배경지식\xa0\r\n', '2.1 네트워크 기본 이론\xa0', '2.2 네트워크 장비\xa0', '2.3 네트워크 보안 시스템\xa0', '2.4 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 3 네트워크 보안 실습 환경 구축\xa0\r\n', '3.1 네트워크 구축\xa0', '3.2 가상 머신 환경 구축\xa0', '3.3 네트워크 시뮬레이터를 이용한 네트워크 구성\xa0', '3.4 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 4 방화벽\xa0\r\n', '4.1 방화벽 장비 제작\xa0', '4.2 방화벽 설치 및 설정\xa0', '4.3 방화벽 운영\xa0', '4.4 마치며', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 5 네트워크 침입 탐지/차단 시스템\xa0\r\n', '5.1 NIDS/NIPS 장비 제작\xa0', '5.2 NIDS/NIPS 네트워크 구성\xa0', '5.3 Suricata\xa0', '5.4 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 6 호스트 기반 침입 탐지/차단 시스템\xa0\r\n', '6.1 OSSEC 설치 및 설정\xa0', '6.2 OSSEC 에이전트 관리\xa0', '6.3 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 7 웹 방화벽\xa0\r\n', '7.1 웹 방화벽 구축\xa0', '7.2 웹 방화벽 정책 관리\xa0', '7.3 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 8 보안 관제 시스템\xa0\r\n', '8.1 보안 관제 구성\xa0', '8.2 ELK를 통한 보안 관제\xa0', '8.3 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 9 보안 취약점 점검을 위한 도구\xa0\r\n', '9.1 네트워크 보안 취약점 진단\xa0', '9.2 네트워크 트래픽 분석\xa0', '9.3 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 10 네트워크 보안 관제 실무\xa0\r\n', '10.1 보안 관제 기본 운영\xa0', '10.2 임계치 기반 공격 탐지와 대응\xa0', '10.3 유해 및 악성 사이트 탐지와 대응\xa0', '10.4 웹 해킹 탐지와 대응\xa0', '10.5 공격 코드 탐지와 대응\xa0', '10.6 서버 및 엔드포인트 공격 탐지와 대응\xa0', '10.7 네트워크 장애 대응\xa0', '10.8 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 11 무선 네트워크 보안\xa0\r\n', '11.1 무선 네트워크 구성 요소\xa0', '11.2 무선 네트워크 접속 방식\xa0', '11.3 무선 네트워크 구축 시 고려사항\xa0', '11.4 무선 네트워크 보안 취약점\xa0', '11.5 무선 네트워크 보안 대응', '11.6 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 12 클라우드 네트워크 보안\xa0\r\n', '12.1 클라우드 형태와 서비스 유형\xa0', '12.2 클라우드 네트워크에서의 보안 위협\xa0', '12.3 클라우드 네트워크에서의 보안 방법\xa0', '12.4 마치며\xa0', '\xa0', '\r\n\t\t\t\t\t\tCHAPTER 13 네트워크 보안의 변화\xa0\r\n', '13.1 네트워크 보안 트렌드', '13.2 보안 관제 트렌드 변화에 따른 고려 사항', '13.3 정보 보안을 위한 인재', '13.4 네트워크 보안 시스템 구축 시 체크 리스트', '13.5 마치며']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B7132069963', 'title': 'IT CookBook, 난생처음 파이썬 프로그래밍', 'price': '24,000', 'content': ['', '\r\n\t\t\t\tChapter 01 파이썬 비긴즈\t\t\t\r\n', '\r\n\t\t\t\t01 프로그래밍 언어란?\t\r\n', '\r\n\t\t\t\t02 파이썬이란?\t\t\r\n', '\r\n\t\t\t\t03 파이썬 설치하고 실행하기\t\t\r\n', '04 파이썬 IDLE 활용하기', '\r\n\t\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 02 변수\t\t\r\n', '\r\n\t\t\t\t01 변수란?\t\t\r\n', '\r\n\t\t\t\t02 변수 이름 짓기\t\t\r\n', '\r\n\t\t\t\t03 값을 입력받는 input() 함수\t\r\n', '[실전 예제] 거북이가 나오는 프로그램', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 03 연산자\t\t\t\r\n', '\r\n\t\t\t\t01 산술 연산자\t\t\r\n', '\r\n\t\t\t\t02 대입 연산자\t\t\r\n', '\r\n\t\t\t\t03 비교 연산자와 논리 연산자\t\t\r\n', '\r\n\t\t\t\t04 연산자의 우선순위\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 거북이를 그리는 펜의 변화\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 입력한 값만큼 거북이 움직이기\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 04 데이터형과 문자열\t\t\t\r\n', '\r\n\t\t\t\t01 데이터형이란?\t\t\r\n', '\r\n\t\t\t\t02 데이터형의 종류\t\t\r\n', '\r\n\t\t\t\t03 문자열 알아보기\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 모험을 떠나는 거북이\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 05 조건문\t\t\t\r\n', '\r\n\t\t\t\t01 조건문의 기초 다지기\t\t\r\n', '\r\n\t\t\t\t02 조건문 알아보기\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 사춘기 거북이를 지도하기\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 06 반복문\t\t\t\r\n', '\r\n\t\t\t\t01 for문 기초 다지기\t\t\r\n', '\r\n\t\t\t\t02 for문 활용하기 \t\t\r\n', '\r\n\t\t\t\t03 while문이란?\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 거북이 무늬의 벽지 만들기\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter07 리스트, 튜플, 딕셔너리\t\t\t\r\n', '\r\n\t\t\t\t01 리스트 기초\t\t\r\n', '\r\n\t\t\t\t02 리스트 활용하기\t\t\r\n', '\r\n\t\t\t\t03 튜플\t\t\r\n', '\r\n\t\t\t\t04 딕셔너리\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 100마리의 거북이 쇼\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 08 함수를 이용한 고급 프로그래밍\t\t\t\r\n', '\r\n\t\t\t\t01 함수 이해하기\t\t\r\n', '\r\n\t\t\t\t02 함수에 매개변수를 전달하고 값 반환하기\t\t\r\n', '\r\n\t\t\t\t03 지역변수와 전역변수\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 훈민정음 그래픽 디자인\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter09 파일 읽기와 쓰기\t\t\t\r\n', '\r\n\t\t\t\t01 파일을 사용하는 이유\t\t\r\n', '\r\n\t\t\t\t02 파일 읽기\t\t\r\n', '\r\n\t\t\t\t03 파일 쓰기\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 갔던 길을 복습하는 거북이\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 10 객체 지향 프로그래밍 \t\t\t\r\n', '\r\n\t\t\t\t01 객체 지향 프로그래밍 이해하기\t\t\r\n', '\r\n\t\t\t\t02 클래스와 객체\t\t\r\n', '\r\n\t\t\t\t03 생성자와 특별한 메소드\t\t\r\n', '\r\n\t\t\t\t04 클래스의 상속\t\t\r\n', '\r\n\t\t\t\t[실전 예제] GPS를 단 토끼\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 11 다양한 라이브러리\t\t\t\r\n', '\r\n\t\t\t\t01 Pillow 라이브러리\t\t\r\n', '\r\n\t\t\t\t02 Pygame 라이브러리\t\t\r\n', '\r\n\t\t\t\t[실전 예제] 룰렛하는 거북이\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 12 Tkinter와 GUI 프로그래밍\t\t\r\n', '\r\n\t\t\t\t01 Tkinter 라이브러리\t\t\r\n', '\r\n\t\t\t\t02 마우스 이벤트 처리하기\t\t\r\n', '\r\n\t\t\t\t03 메뉴와 대화상자 만들기\t\t\r\n', '\r\n\t\t\t\t[실전 예제] GUI로 편하게 거북이 그리기\t\t\r\n', '\r\n\t\t\t\t\t\t\t\r\n', '\r\n\t\t\t\tChapter 13 프로젝트: 포토 에디터\t\t\t\r\n', '\r\n\t\t\t\t01 [포토 에디터] 기본 구성\t\t\r\n', '02 [포토 에디터] 기능 구현']}
# {'url': 'https://www.hanbit.co.kr/store/books/look.php?p_code=B8742050283', 'title': 'IT CookBook, 정보 보안 개론(4판)', 'price': '30,000', 'content': ['', '\r\n\t\t\t\t\t\tChapter 01 정보 보안의 세계\r\n', '01 정보 보안의 역사', '02 정보 보안의 이해', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 02 시스템 보안\r\n', '01 시스템 보안의 이해', '02 계정 관리', '03 세션 관리', '04 접근 제어', '05 권한 관리', '06 로그 관리', '07 취약점 관리', '08 모바일 보안', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 03 네트워크 보안\r\n', '01 네트워크의 이해', '02 서비스 거부 공격: Dos와 DDos', '03 스니핑 공격', '04 스푸핑 공격', '05 세션 하이재킹 공격', '06 무선 네트워크 공격과 보안', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 04 웹 보안\r\n', '01 웹과 HTTP의 이해', '02 웹 서비스의 이해', '03 웹 해킹', '04 웹의 취약점과 보안', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 05 코드 보안\r\n', '01 시스템 구성과 프로그램 동작', '02 버퍼 오버플로 공격', '03 포맷 스트링 공격', '04 메모리 해킹', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 06 악성 코드\r\n', '01 악성 코드', '02 바이러스', '03 웜', '04 트로이 목마', '05 PUP', '06 악성 코드 탐지 및 대응책', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 07 암호의 이해\r\n', '01 암호의 개념과 원리', '02 대칭 암호화 방식', '03 비대칭 암호화 방식', '04 해시', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 08 전자 상거래 보안\r\n', '01 전자 상거래의 이해', '02 공개 키 기반 구조', '03 전자 서명과 전자 봉투', '04 전자 결제와 가상 화폐', '05 암호화 통신', '06 콘테츠 보안', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 09 보안 시스템\r\n', '01 인증 시스템', '02 방화벽', '03 침입 탐지 시스템', '04 침입 방지 시스템', '05 통제 및 감시 장비', '06 기타 보안 솔루션', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 10 IoT 보안과 AI 보안\r\n', '01 IoT 보안', '02 AI에 대한 이해', '03 AI의 취약점 유형과 대안', '04 AI를 이용한 보안', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 11 침해 대응과 디지털 포렌식\r\n', '01 침해 대응', '02 디지털 포렌식의 개념과 절차', '03 디지털 포렌식의 증거 수집', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 12 사회공학\r\n', '01 사회공학의 이해', '02 사회공학 기법', '03 사회공학 사례와 대응책', '요약', '연습문제', '\xa0', '\r\n\t\t\t\t\t\tChapter 13 보안 관리\r\n', '01 보안 거버넌스', '02 보안 프레임워크', '03 보안 조직', '04 보안 정책과 절차', '05 접근 제어 모델', '06 내부 통제', '07 보안 인증', '08 개인 정보 보호', '요약', '연습문제', '\xa0', '부록', '찾아보기']}
